# %% [markdown]
# # 편리한 정보의 시각화

# %% [markdown]
# ### 데이터 시각화의 필요성

# %% [markdown]
# + 정보를 상대방에게 빠르고 쉽게 이해시키기 위해 시각화를 한다
# + R언어는 데이터의 처리와 처리된 데이터를 시각화하는 도구를 제공하며, 많은 양의 데이터를 시각화하는 문제를 해결할 수 있다
# + R언어의 기본 패키지에는 그래픽 기능을 지원하는 Graphics 패키지가 있다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kor <- c(61, 78 , 95, 80, 72)
plot(kor, type="b", pch=1)
# Out:
# plot without title

# %% [markdown]
# + plot의 첫 부분에는 반드시 벡터나 행렬형태가 들어가야 한다
# + type은 어떤 형태로 만들것인지 pch는 어떤 마크를 이용할 것인지에 대한 plot의 옵션
# ![image.png](attachment:image.png)

# %%
kor <- c(61, 78, 95, 80, 72)
eng <- c(81, 87, 90, 70, 82)
plot(kor, type="b", pch=1)

points(eng,type="b",pch=2, lty = 2, lwd = 2)
grid()
txt = c("kor","eng")
legend("topright",txt,pch=1:2, bty = "n")
# Out:
# plot without title

# %% [markdown]
# + point()함수는 이미 그려져 있는 plot위에 새로운 그래프나 포인트를 그려라 라는 함수
# + grid()함수는 그래프에 선을 표시함
# + legend()는 범례를 설정하는 함수
# + topright는 오른쪽 위에 범례를 넣으라는 의미
# + bty는 범례를 표시하는 경계선을 의미

# %%
kor <- c(61, 78, 95, 80, 72)
no <- c(201701, 201702, 201703, 201704, 201705)
plot(no,kor)
# Out:
# plot without title

# %%
data("pressure")
print(head(pressure))
plot(pressure)
grid()
# Out:
#   temperature pressure
# 1           0   0.0002
# 2          20   0.0012
# 3          40   0.0060
# 4          60   0.0300
# 5          80   0.0900
# 6         100   0.2700
# plot without title

# %%
data("pressure")
plot(pressure, type="b",
     xlim = c(0,400),
     ylim = c(0,850),
     main = "Temp. , & Pres.",
     xlab = "온도", ylab = "기압",
     cex.lab = 1.1,
     col = 2)
grid()
# Out:
# Plot with title "Temp. , & Pres."

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot(pressure)
title(main = "온도와 기압간의 관계", col.main = "dark blue")
arrows(100, 200, 150, 10)
text(110, 250, "temperature & pressure", cex = 1.2, col = "blue")
points(200, 600, pch = 8, cex = 2)
# Out:
# Plot with title "온도와 기압간의 관계"

# %%
data <- c(203, 325, 412, 500, 120)
name <- c("금정점", "서구점", "동구점", "사상점", "중구점")
barplot(data,
        main = "가맹점별 판매실적",
        names.arg = name,
        col = c("black", "red", "green", "blue", "cyan"),
        ylab = "판매실적(백만원)", ylim = c(0,600))
# Out:
# Plot with title "가맹점별 판매실적"

# %%
setwd("D:/R with Big Data/강의 실습자료/ch_07")
kor <- scan("ch7_1_kor.txt")
print(kor)
hist(kor,
     breaks = 10,
     freq = FALSE,
     col = c("red", "blue", "green"), main = "국어 점수의 분포", # col=rainbow(!0)으로 여러가지 색으로 표현할 수 있다.
     xlab = "국어점수", ylab = "미흡")
# Out:
#  [1] 80 70 90 70 80 75 60 70 80 52 40 86 92 90 75 98 65 78 72 40
# Plot with title "국어 점수의 분포"

# %%
x <- c(203, 325, 412, 500, 120)
lbl <- c("금정점", "서구점", "동구점", "사상점", "중구점")
pie(x, main = "가맹점별 판매실적",
    labels = lbl,
    radius = 1.0,
    col = rainbow(length(x)))
# Out:
# Plot with title "가맹점별 판매실적"

# %%
setwd("D:/R with Big Data/강의 실습자료/ch_07")
kor <- scan("ch7_1_kor.txt")
boxplot(kor, main = "국어 점수의 분포", ylab = "점수", col =5)
print(max(kor));print(min(kor)); print(median(kor))
# Out:
# [1] 98
# [1] 40
# [1] 75
# Plot with title "국어 점수의 분포"

# %% [markdown]
# ### 데이터의 시각화의 정보찾기

# %% [markdown]
# + 주어진 데이터를 다양한 관점에서 볼 수 있도록 시각화하는 방법이 필요하다
# + 사용자가 원하는 정보의 초점에 따라 데이터를 시각화해야 한다

# %%
setwd("D:/R with Big Data/강의 실습자료/ch_07")
data = read.table("ch7_2_1_student.txt", header = TRUE, stringsAsFactor= FALSE)

barplot(data$kor, main = "국어 성적", ylim=c(0,100), xlab = "이름", ylab = "점수",
        names.arg=data$name, col=c(1,2,3,4,5,6))
barplot(data$eng, main = "영어 성적", ylim=c(0,100), xlab = "이름", ylab = "점수",
        names.arg=data$name, col=c(1,2,3,4,5,6))
barplot(data$mat, main = "수학 성적", ylim=c(0,100), xlab = "이름", ylab = "점수",
        names.arg=data$name, col=c(1,2,3,4,5,6))
# Out:
# Plot with title "국어 성적"
# Plot with title "영어 성적"
# Plot with title "수학 성적"

# %%
setwd("D:/R with BIg Data/강의 실습자료/ch_07")
data <- read.table("ch7_2_1_student.txt", header= TRUE, stringsAsFactor = FALSE)

data1 <- data[,-1] # 첫열은 제외
data2 <- as.matrix(data1)
name <- c("국어","영어","수학")

barplot(data2, main = "과목별 성적", names.arg = name, ylim = c(0,150),
        ylab = "점수", col = rainbow(nrow(data2)), beside = TRUE)

legend(1,140, data$name, cex = 0.8, fill = rainbow(nrow(data2)), horiz = T)
# Out:
# Plot with title "과목별 성적"

# %% [markdown]
# + horiz 는 수평으로 하라는 함수

# %%
setwd("D:/R with BIg Data/강의 실습자료/ch_07")
data <- read.table("ch7_2_1_student.txt", header= TRUE, stringsAsFactor = FALSE)

data1 <- data[,-1] # 첫열은 제외
data2 <- t(data1)

barplot(data2, names.arg=data$name, ylim=c(0,350), ylab="점수",
        border="cyan", col = c(2,3,4), beside = FALSE)
legend("topright",c("국어","영어","수학"), cex=0.7, bty = "n",
       fill = c(2,3,4), horiz = T)
# Out:
# plot without title

# %% [markdown]
# + beside = FALSE는 위로 누적
